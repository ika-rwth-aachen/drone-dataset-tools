# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirD:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tools.TrajectoryUtils import TrajectoryUtils
import pandas as pd

# %%
csvFile = "../data/crossing.csv"
crossingDf = pd.read_csv(csvFile)

# %%
crossingDf.head()
# Out:
#    Unnamed: 0  recordingId  trackId  frame  trackLifetime   xCenter   yCenter  \
# 0           0           18       23    286              0  47.32667 -10.09111
# 1           1           18       23    287              1  47.36134 -10.12231
# 2           2           18       23    288              2  47.39602 -10.15368
# 3           3           18       23    289              3  47.43071 -10.18521
# 4           4           18       23    290              4  47.46540 -10.21692
#
#      heading  width  length  xVelocity  yVelocity  xAcceleration  \
# 0  316.84658    0.0     0.0    0.85962   -0.78300       -0.00390
# 1  316.83139    0.0     0.0    0.85997   -0.78700       -0.00491
# 2  316.81295    0.0     0.0    0.86016   -0.79111       -0.00629
# 3  316.79140    0.0     0.0    0.86019   -0.79532       -0.00793
# 4  316.76687    0.0     0.0    0.86003   -0.79962       -0.00974
#
#    yAcceleration  lonVelocity  latVelocity  lonAcceleration  latAcceleration  \
# 0       -0.08807      1.16265     -0.01672          0.05739          0.06691
# 1       -0.08913      1.16564     -0.01435          0.05739          0.06837
# 2       -0.08979      1.16859     -0.01186          0.05687          0.06977
# 3       -0.08998      1.17149     -0.00925          0.05583          0.07101
# 4       -0.08964      1.17431     -0.00652          0.05430          0.07198
#
#    uniqueTrackId  sceneId
# 0          18023       10
# 1          18023       10
# 2          18023       10
# 3          18023       10
# 4          18023       10

# %%
aTraj = crossingDf[crossingDf["uniqueTrackId"] == 18023]

# %%
len(aTraj)
# Out:
# 799

# %%
downTraj = TrajectoryUtils.downSample(aTraj, 25.0, 2.5).convert_dtypes()

# %%
len(downTraj)
# Out:
# 80

# %%
downTraj.head()
# Out:
#     Unnamed: 0  recordingId  trackId  frame  trackLifetime   xCenter  \
# 0            0           18       23    286              0  47.32667
# 10          10           18       23    296             10  47.67505
# 20          20           18       23    306             20  48.00758
# 30          30           18       23    316             30  48.35553
# 40          40           18       23    326             40  48.70924
#
#      yCenter    heading  width  length  xVelocity  yVelocity  xAcceleration  \
# 0  -10.09111  316.84658      0       0    0.85962   -0.78300       -0.00390
# 10 -10.41453  316.56418      0       0    0.85224   -0.82068       -0.01403
# 20 -10.74370  316.08628      0       0    0.85307   -0.85612        0.03110
# 30 -11.09895  315.54290      0       0    0.87141   -0.88267        0.02578
# 40 -11.45365  315.00692      0       0    0.87700   -0.87984       -0.00496
#
#     yAcceleration  lonVelocity  latVelocity  lonAcceleration  latAcceleration  \
# 0        -0.08807      1.16265     -0.01672          0.05739          0.06691
# 10       -0.08197      1.18310      0.00998          0.04617          0.06917
# 20       -0.08286      1.20832      0.02507          0.07987          0.03812
# 30       -0.02409      1.24019      0.01972          0.03528         -0.00086
# 40        0.01254      1.24228      0.00216         -0.01238         -0.00536
#
#     uniqueTrackId  sceneId
# 0           18023       10
# 10          18023       10
# 20          18023       10
# 30          18023       10
# 40          18023       10
