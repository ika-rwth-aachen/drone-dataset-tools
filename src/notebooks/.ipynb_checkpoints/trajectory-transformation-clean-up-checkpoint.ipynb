# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"
dataDir = "E:/AV/DataSetExploration/drone-dataset-tools/data/location-2/home"

# %%
exec(open('init_notebook.py').read())
# %load_ext autoreload
# %autoreload 2
# %tb
# Out:
# current working dirE:\AV\DataSetExploration\drone-dataset-tools\src
# No traceback available to show.

# %%
import logging
logging.basicConfig(level=logging.INFO)
from loguru import logger
logger.remove()
logger.add(sys.stdout, format="{level} {message}", filter="my_module", level="INFO")
import seaborn as sns

from extractors.loader import Loader
from tools.TrajectoryUtils import TrajectoryUtils
from tools.TrajectoryVisualizer import TrajectoryVisualizer
import matplotlib.pyplot as plt
import numpy as np
visualizer = TrajectoryVisualizer(None)

# %%
from extractors.LocationData import LocationData
sceneData = LocationData.load("../data/location-2/home", "2022-12-09-fps-5-scene-21.dill")
pedDf = sceneData.getPedDataInSceneCoordinates()
otherDf = sceneData.getOtherDataInSceneCoordinates()
sceneMeta = sceneData.getMeta()

# %%
visualizer.showLocationSceneData(sceneData, onlyClipped=False, showLocal=False, showOthers=True, ids=[21426, 21549, 28230, 29106, 29238, 29240])

# %%
pedDf[['xVelocity', 'yVelocity']].describe()
# Out:
#          xVelocity    yVelocity
# count  1437.000000  1437.000000
# mean     -0.107161    -0.025021
# std       1.155965     1.123200
# min      -3.307180    -1.892070
# 25%      -0.538140    -1.149660
# 50%      -0.154790    -0.127480
# 75%       0.368420     1.119610
# max       5.649980     2.136650

# %%
sns.boxplot(pedDf['xVelocity'])
# Out:
# C:\Users\adhocmaster\.conda\envs\drone\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from tti_dataset_tools.TrajectoryTransformer import TrajectoryTransformer
from tti_dataset_tools.TrajectoryVisualizer import TrajectoryVisualizer
from tti_dataset_tools.TrajectoryCleaner import TrajectoryCleaner
from tti_dataset_tools.ColMapper import ColMapper
visualizer = TrajectoryVisualizer()
colMapper = ColMapper(
        idCol='uniqueTrackId', 
        xCol='sceneX', 
        yCol='sceneY',
        xVelCol='xVelocity', 
        yVelCol='xVelocity', 
        speedCol='speed'
    )
transformer = TrajectoryTransformer(colMapper)
cleaner = TrajectoryCleaner(
    colMapper = colMapper,
    minSpeed = 0.0,
    maxSpeed = 3.0,
    minYDisplacement = 5.0,
    maxXDisplacement = 8.0,
)

# %%
transformer.deriveSpeed(sceneData.pedData)
transformer.deriveDisplacements(sceneData.pedData)
pedDf.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\drone\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sceneX'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e6f4259a7351> in <module>
#       1 transformer.deriveSpeed(sceneData.pedData)
# ----> 2 transformer.deriveDisplacements(sceneData.pedData)
#       3 pedDf.describe()
#
# E:\AV\DataSetExploration\TTI-dataset-tools\src\tti_dataset_tools\TrajectoryTransformer.py in deriveDisplacements(self, tracksDf)
#      87         # displacement wrt the first row
#      88         firstRow = tracksDf.iloc[0]
# ---> 89         firstX = firstRow[self.xCol]
#      90         firstY = firstRow[self.yCol]
#      91
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'sceneX'

# %%
transformer.deriveSpeed(pedDf)
# transformer.deriveDisplacements(pedDf)
pedDf.describe()
# Out:
#                index  recordingId      trackId         frame  trackLifetime  \
# count    1437.000000  1437.000000  1437.000000   1437.000000    1437.000000
# mean   151147.897704    23.874739   291.219207  16150.919276     468.865692
# std     91670.623884     3.538827   154.618269   8826.547288     224.464158
# min      9260.000000    18.000000    16.000000    570.000000      10.000000
# 25%     71160.000000    21.000000   211.000000  10341.000000     325.000000
# 50%    148921.000000    24.000000   288.000000  15657.000000     460.000000
# 75%    232227.000000    27.000000   395.000000  22841.000000     605.000000
# max    289574.000000    29.000000   586.000000  31650.000000    1290.000000
#
#            xCenter      yCenter      heading   width  length  ...  roadWidth  \
# count  1437.000000  1437.000000  1437.000000  1437.0  1437.0  ...     1437.0
# mean     31.078826   -33.023563   187.890036     0.0     0.0  ...        9.0
# std       5.238440     2.874328    91.421253     0.0     0.0  ...        0.0
# min      21.762710   -40.170470     0.301540     0.0     0.0  ...        9.0
# 25%      25.235410   -35.059520   105.393060     0.0     0.0  ...        9.0
# 50%      32.555640   -32.729470   185.122370     0.0     0.0  ...        9.0
# 75%      35.966420   -31.103930   266.931600     0.0     0.0  ...        9.0
# max      37.834650   -27.357230   358.992730     0.0     0.0  ...        9.0
#
#             sceneX       sceneY  sceneXVelocity  sceneYVelocity  \
# count  1437.000000  1437.000000     1437.000000     1437.000000
# mean      1.656123     0.301633        0.108469       -0.006017
# std       5.404101     2.549257        1.177875        1.103737
# min      -7.429797    -4.761115       -6.010263       -2.012759
# 25%      -3.764739    -1.846834       -0.207005       -1.091347
# 50%       3.064096     0.699638        0.089604       -0.148629
# 75%       6.935669     2.385241        0.604625        1.083675
# max       7.801142     4.734512        3.378489        1.845924
#
#        sceneXAcceleration  sceneYAcceleration        speed  displacementX  \
# count         1437.000000         1437.000000  1437.000000    1437.000000
# mean            -0.010428           -0.003096     1.073529       5.444630
# std              0.355469            0.303622     1.241864       5.268630
# min             -1.758291           -1.100709     0.000905       0.000000
# 25%             -0.199982           -0.171317     0.348674       0.292785
# 50%             -0.000836           -0.001037     0.637556       3.902314
# 75%              0.186201            0.171007     1.407454      10.731149
# max              2.001175            1.306338     7.990278      14.396207
#
#        displacementY
# count    1437.000000
# mean        4.689997
# std         2.540027
# min         0.000000
# 25%         2.536523
# 50%         5.082995
# 75%         6.768598
# max         9.117868
#
# [8 rows x 25 columns]

# %%
sns.boxplot(pedDf['speed'])
# Out:
# C:\Users\adhocmaster\.conda\envs\drone\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
outliers = cleaner.getOutliersBySpeed(sceneData.pedData, byIQR=True, returnVals=True)
outliers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-a3017284db4a> in <module>
# ----> 1 outliers = cleaner.getOutliersBySpeed(sceneData.pedData, byIQR=True, returnVals=True)
#       2 outliers
#
# E:\AV\DataSetExploration\TTI-dataset-tools\src\tti_dataset_tools\TrajectoryCleaner.py in getOutliersBySpeed(self, tracksDf, byIQR, returnVals)
#      75                 self.speedCol,
#      76                 byIQR=byIQR,
# ---> 77                 returnVals=returnVals
#      78             )
#      79
#
# E:\AV\DataSetExploration\TTI-dataset-tools\src\tti_dataset_tools\TrajectoryCleaner.py in getOutliersByCol(self, tracksDf, col, byIQR, returnVals)
#      33
#      34
# ---> 35         maxVals = tracksDf[[self.idCol, col]].groupby([self.idCol]).max()
#      36
#      37         if byIQR:
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['speed'] not in index"

# %%
outliers = cleaner.getOutliersBySpeed(sceneData.pedData, byIQR=False, returnVals=True)
print(outliers)

# %%
print(sceneData.uniquePedIds())
print(sceneData.uniqueOtherIds())

# %%
sceneData.moveOutlierPedsToOthers(transformer, cleaner)
print(sceneData.uniquePedIds())
print(sceneData.uniqueOtherIds())

# %%
sceneData.warnings
