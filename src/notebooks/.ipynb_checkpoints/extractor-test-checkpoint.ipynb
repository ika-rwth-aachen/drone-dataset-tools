# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirE:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from extractors.loader import Loader

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"

# %%
loader = Loader(dataDir, 'inD')

# %%
tracksDf, tracksMetaDf, recordingMetaDf = loader.getRecordingData('30')

# %%
tracksMetaDf.head()
# Out:
#    recordingId  trackId  initialFrame  finalFrame  numFrames    width  \
# 0           30        0             0         164        165  1.95184
# 1           30        1             0       25613      25614  2.07064
# 2           30        2             0       25613      25614  2.23145
# 3           30        3             0       25613      25614  2.11827
# 4           30        4             0       25613      25614  2.07056
#
#     length class
# 0  4.83186   car
# 1  4.19739   car
# 2  5.34932   car
# 3  4.75119   car
# 4  4.83091   car

# %%
tracksDf.tail()
# Out:
#         recordingId  trackId  frame  trackLifetime   xCenter   yCenter  \
# 287005           30      410  25609            103  56.53556 -43.11588
# 287006           30      410  25610            104  56.97220 -43.44953
# 287007           30      410  25611            105  57.40950 -43.78221
# 287008           30      410  25612            106  57.84670 -44.11397
# 287009           30      410  25613            107  58.28266 -44.44682
#
#           heading    width   length  xVelocity  yVelocity  xAcceleration  \
# 287005  322.89039  1.88283  4.02104   10.93307   -8.34166       -0.22153
# 287006  322.78327  1.88283  4.02104   10.92464   -8.33784       -0.22114
# 287007  322.70977  1.88283  4.02104   10.91603   -8.33428       -0.22108
# 287008  322.62479  1.88283  4.02104   10.90713   -8.33131       -0.22111
# 287009  322.51791  1.88283  4.02104   10.89828   -8.32849       -0.22111
#
#         yAcceleration  lonVelocity  latVelocity  lonAcceleration  \
# 287005        0.06867     13.75180      0.05595         -0.21810
# 287006        0.07010     13.74286      0.03230         -0.21850
# 287007        0.07062     13.73388      0.01705         -0.21867
# 287008        0.07069     13.72502     -0.00027         -0.21862
# 287009        0.07069     13.71626     -0.02273         -0.21847
#
#         latAcceleration uniqueTrackId
# 287005          0.07890        30-410
# 287006          0.07793        30-410
# 287007          0.07776        30-410
# 287008          0.07805        30-410
# 287009          0.07846        30-410

# %%
pedIds = loader.getSortedPedIds(tracksMetaDf)

# %%
pedFrames = loader.extractPedFrames(tracksMetaDf, tracksDf)

# %%
pedFrames.tail()
# Out:
#         recordingId  trackId  frame  trackLifetime   xCenter   yCenter  \
# 286454           30      406  25609            357  58.69731 -11.28733
# 286455           30      406  25610            358  58.73357 -11.27016
# 286456           30      406  25611            359  58.77014 -11.25270
# 286457           30      406  25612            360  58.80706 -11.23494
# 286458           30      406  25613            361  58.84430 -11.21655
#
#          heading  width  length  xVelocity  yVelocity  xAcceleration  \
# 286454  23.35921    0.0     0.0    0.89340    0.42495        0.29689
# 286455  23.55346    0.0     0.0    0.90526    0.43440        0.29678
# 286456  23.74740    0.0     0.0    0.91707    0.44388        0.29671
# 286457  23.94101    0.0     0.0    0.92887    0.45344        0.29668
# 286458  24.13428    0.0     0.0    0.94074    0.46297        0.29668
#
#         yAcceleration  lonVelocity  latVelocity  lonAcceleration  \
# 286454        0.23836      0.98866     -0.03590          0.36706
# 286455        0.23830      1.00342     -0.03646          0.36728
# 286456        0.23830      1.01817     -0.03699          0.36755
# 286457        0.23831      1.03296     -0.03749          0.36786
# 286458        0.23831      1.04781     -0.03785          0.36819
#
#         latAcceleration
# 286454         -0.10111
# 286455         -0.09985
# 286456         -0.09864
# 286457         -0.09741
# 286458         -0.09617

# %%
rMeta = loader.getAllRecordingMeta()
# Out:
# ['G:AV datasets/inD-dataset-v1.0/data/00_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/01_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/02_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/03_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/04_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/05_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/06_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/07_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/08_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/09_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/10_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/11_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/12_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/13_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/14_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/15_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/16_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/17_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/18_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/19_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/20_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/21_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/22_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/23_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/24_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/25_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/26_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/27_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/28_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/29_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/30_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/31_recordingMeta.csv', 'G:AV datasets/inD-dataset-v1.0/data/32_recordingMeta.csv']

# %%
rMeta
# Out:
# [{'recordingId': 0,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'wednesday',
#   'startTime': 16,
#   'duration': 961.08,
#   'numTracks': 384,
#   'numVehicles': 324,
#   'numVRUs': 60,
#   'latLocation': 50.78505,
#   'lonLocation': 6.1307,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 1,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 15,
#   'duration': 1032.32,
#   'numTracks': 385,
#   'numVehicles': 355,
#   'numVRUs': 30,
#   'latLocation': 50.78505,
#   'lonLocation': 6.13068,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 2,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 15,
#   'duration': 905.56,
#   'numTracks': 392,
#   'numVehicles': 341,
#   'numVRUs': 51,
#   'latLocation': 50.78504,
#   'lonLocation': 6.13068,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 3,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 12,
#   'duration': 1026.88,
#   'numTracks': 304,
#   'numVehicles': 274,
#   'numVRUs': 30,
#   'latLocation': 50.785059999999994,
#   'lonLocation': 6.13068,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 4,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 12,
#   'duration': 647.68,
#   'numTracks': 182,
#   'numVehicles': 177,
#   'numVRUs': 5,
#   'latLocation': 50.785059999999994,
#   'lonLocation': 6.130719999999999,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 5,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 13,
#   'duration': 941.2,
#   'numTracks': 312,
#   'numVehicles': 287,
#   'numVRUs': 25,
#   'latLocation': 50.785059999999994,
#   'lonLocation': 6.130730000000001,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 6,
#   'locationId': 4,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 14,
#   'duration': 1096.04,
#   'numTracks': 388,
#   'numVehicles': 340,
#   'numVRUs': 48,
#   'latLocation': 50.78505,
#   'lonLocation': 6.1307,
#   'xUtmOrigin': 297631.3187,
#   'yUtmOrigin': 5629917.34465,
#   'orthoPxToMeter': 0.0126999352667008},
#  {'recordingId': 7,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': nan,
#   'duration': 1055.28,
#   'numTracks': 212,
#   'numVehicles': 150,
#   'numVRUs': 62,
#   'latLocation': 50.782070000000004,
#   'lonLocation': 6.07116,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 8,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': nan,
#   'duration': 1065.6,
#   'numTracks': 415,
#   'numVehicles': 284,
#   'numVRUs': 131,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.0711699999999995,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 9,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': nan,
#   'duration': 783.68,
#   'numTracks': 236,
#   'numVehicles': 168,
#   'numVRUs': 68,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.07118,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 10,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': nan,
#   'duration': 854.04,
#   'numTracks': 253,
#   'numVehicles': 190,
#   'numVRUs': 63,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.07116,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 11,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 16,
#   'duration': 901.6,
#   'numTracks': 305,
#   'numVehicles': 214,
#   'numVRUs': 91,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.07116,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 12,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 16,
#   'duration': 1126.88,
#   'numTracks': 410,
#   'numVehicles': 268,
#   'numVRUs': 142,
#   'latLocation': 50.782070000000004,
#   'lonLocation': 6.07118,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 13,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 16,
#   'duration': 994.64,
#   'numTracks': 357,
#   'numVehicles': 231,
#   'numVRUs': 126,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.07116,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 14,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'monday',
#   'startTime': 17,
#   'duration': 1004.84,
#   'numTracks': 379,
#   'numVehicles': 226,
#   'numVRUs': 153,
#   'latLocation': 50.7821,
#   'lonLocation': 6.07114,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 15,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesdays',
#   'startTime': 15,
#   'duration': 1083.04,
#   'numTracks': 345,
#   'numVehicles': 230,
#   'numVRUs': 115,
#   'latLocation': 50.782090000000004,
#   'lonLocation': 6.0711699999999995,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 16,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesdays',
#   'startTime': 15,
#   'duration': 1201.0,
#   'numTracks': 450,
#   'numVehicles': 280,
#   'numVRUs': 170,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.0712,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 17,
#   'locationId': 1,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesdays',
#   'startTime': 16,
#   'duration': 1050.44,
#   'numTracks': 376,
#   'numVehicles': 262,
#   'numVRUs': 114,
#   'latLocation': 50.782059999999994,
#   'lonLocation': 6.0712,
#   'xUtmOrigin': 293487.1224,
#   'yUtmOrigin': 5629711.58163,
#   'orthoPxToMeter': 0.008146360917249159},
#  {'recordingId': 18,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 16,
#   'duration': 1119.64,
#   'numTracks': 427,
#   'numVehicles': 181,
#   'numVRUs': 246,
#   'latLocation': 50.768359999999994,
#   'lonLocation': 6.10227,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 19,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 16,
#   'duration': 993.44,
#   'numTracks': 370,
#   'numVehicles': 156,
#   'numVRUs': 214,
#   'latLocation': 50.76835,
#   'lonLocation': 6.10228,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 20,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 16,
#   'duration': 1301.72,
#   'numTracks': 499,
#   'numVehicles': 210,
#   'numVRUs': 289,
#   'latLocation': 50.76835,
#   'lonLocation': 6.10227,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 21,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 17,
#   'duration': 1244.28,
#   'numTracks': 550,
#   'numVehicles': 218,
#   'numVRUs': 332,
#   'latLocation': 50.76835,
#   'lonLocation': 6.10225,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 22,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 17,
#   'duration': 1231.64,
#   'numTracks': 562,
#   'numVehicles': 218,
#   'numVRUs': 344,
#   'latLocation': 50.76838,
#   'lonLocation': 6.10227,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 23,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 18,
#   'duration': 1263.92,
#   'numTracks': 575,
#   'numVehicles': 205,
#   'numVRUs': 370,
#   'latLocation': 50.768390000000004,
#   'lonLocation': 6.10225,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 24,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'tuesday',
#   'startTime': 18,
#   'duration': 954.92,
#   'numTracks': 423,
#   'numVehicles': 147,
#   'numVRUs': 276,
#   'latLocation': 50.768390000000004,
#   'lonLocation': 6.10231,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 25,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'wednesday',
#   'startTime': 16,
#   'duration': 1247.8,
#   'numTracks': 539,
#   'numVehicles': 227,
#   'numVRUs': 312,
#   'latLocation': 50.768370000000004,
#   'lonLocation': 6.10227,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 26,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'wednesday',
#   'startTime': 16,
#   'duration': 1299.28,
#   'numTracks': 547,
#   'numVehicles': 232,
#   'numVRUs': 315,
#   'latLocation': 50.768440000000005,
#   'lonLocation': 6.10229,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 27,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'wednesday',
#   'startTime': 17,
#   'duration': 1328.28,
#   'numTracks': 594,
#   'numVehicles': 203,
#   'numVRUs': 391,
#   'latLocation': 50.76845,
#   'lonLocation': 6.10226,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 28,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'wednesday',
#   'startTime': 17,
#   'duration': 1269.4,
#   'numTracks': 536,
#   'numVehicles': 211,
#   'numVRUs': 325,
#   'latLocation': 50.76845,
#   'lonLocation': 6.10226,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 29,
#   'locationId': 2,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'wednesday',
#   'startTime': 17,
#   'duration': 1299.32,
#   'numTracks': 613,
#   'numVehicles': 228,
#   'numVRUs': 385,
#   'latLocation': 50.768440000000005,
#   'lonLocation': 6.10227,
#   'xUtmOrigin': 295620.9575,
#   'yUtmOrigin': 5628102.04258,
#   'orthoPxToMeter': 0.00814636091724502},
#  {'recordingId': 30,
#   'locationId': 3,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'thursday',
#   'startTime': 13,
#   'duration': 1024.56,
#   'numTracks': 411,
#   'numVehicles': 381,
#   'numVRUs': 30,
#   'latLocation': 50.77887,
#   'lonLocation': 6.16553,
#   'xUtmOrigin': 300127.0853,
#   'yUtmOrigin': 5629091.0587,
#   'orthoPxToMeter': 0.00814635379575616},
#  {'recordingId': 31,
#   'locationId': 3,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'thursday',
#   'startTime': 13,
#   'duration': 1025.8,
#   'numTracks': 401,
#   'numVehicles': 377,
#   'numVRUs': 24,
#   'latLocation': 50.7788,
#   'lonLocation': 6.16554,
#   'xUtmOrigin': 300127.0853,
#   'yUtmOrigin': 5629091.0587,
#   'orthoPxToMeter': 0.00814635379575616},
#  {'recordingId': 32,
#   'locationId': 3,
#   'frameRate': 25.0,
#   'speedLimit': 13.88889,
#   'weekday': 'thursday',
#   'startTime': 14,
#   'duration': 1013.44,
#   'numTracks': 467,
#   'numVehicles': 438,
#   'numVRUs': 29,
#   'latLocation': 50.77881,
#   'lonLocation': 6.16552,
#   'xUtmOrigin': 300127.0853,
#   'yUtmOrigin': 5629091.0587,
#   'orthoPxToMeter': 0.00814635379575616}]
