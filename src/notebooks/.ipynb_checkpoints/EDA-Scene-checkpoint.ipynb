# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"
dataDir = "E:/Datasets/inD-dataset-v1.0/data/"

# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirD:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tools.TrajectoryUtils import TrajectoryUtils
from tools.TrajectoryVisualizer import TrajectoryVisualizer
import matplotlib.pyplot as plt
import numpy as np
visualizer = TrajectoryVisualizer(None)

# %%
# import pandas as pd
# pedDf = pd.read_csv("../data/location-2/2022-11-19-fps-2.5-scene-31-pedestrians.csv")
# otherDf = pd.read_csv("../data/location-2/2022-11-19-fps-2.5-scene-31-others.csv")
# pedDf.head()

# %%
from extractors.LocationData import LocationData
sceneData = LocationData.load("../data/location-2", "2023-05-04-fps-10-scene-240.dill")
# Out:
# 2023-05-07 19:04:28.830 | INFO     | extractors.LocationData:load:530 - reading from ../data/location-2\2023-05-04-fps-10-scene-240.dill

# %%
sceneData.backgroundImagePath = "G:AV datasets/inD-dataset-v1.0/data/18_background.png"

# %%
visualizer.showLocationSceneData(sceneData, onlyClipped=False, showOthers=False)
# visualizer.showLocationSceneData(sceneData, onlyClipped=True)
# Out:
# 2023-03-03 09:37:11.408 | INFO     | tools.TrajectoryVisualizer:initPlot:33 - Loading background image from E:/Datasets/inD-dataset-v1.0/data/18_background.png

# %%
pedDf = sceneData.getPedDataInSceneCoordinates()
otherDf = sceneData.getOtherDataInSceneCoordinates()
sceneMeta = sceneData.getMeta()

# %%
pedDf.groupby(["uniqueTrackId"]).count()
# Out:
#                index  recordingId  trackId  frame  trackLifetime  xCenter  \
# uniqueTrackId
# 18023             23           23       23     23             23       23
# 18042             27           27       27     27             27       27
# 18053             25           25       25     25             25       25
# 18069             18           18       18     18             18       18
# 18090             14           14       14     14             14       14
# ...              ...          ...      ...    ...            ...      ...
# 29542             18           18       18     18             18       18
# 29554             16           16       16     16             16       16
# 29559             18           18       18     18             18       18
# 29575              9            9        9      9              9        9
# 29579             15           15       15     15             15       15
#
#                yCenter  heading  width  length  ...  xAcceleration  \
# uniqueTrackId                                   ...
# 18023               23       23     23      23  ...             23
# 18042               27       27     27      27  ...             27
# 18053               25       25     25      25  ...             25
# 18069               18       18     18      18  ...             18
# 18090               14       14     14      14  ...             14
# ...                ...      ...    ...     ...  ...            ...
# 29542               18       18     18      18  ...             18
# 29554               16       16     16      16  ...             16
# 29559               18       18     18      18  ...             18
# 29575                9        9      9       9  ...              9
# 29579               15       15     15      15  ...             15
#
#                yAcceleration  sceneId  roadWidth  sceneX  sceneY  \
# uniqueTrackId
# 18023                     23       23         23      23      23
# 18042                     27       27         27      27      27
# 18053                     25       25         25      25      25
# 18069                     18       18         18      18      18
# 18090                     14       14         14      14      14
# ...                      ...      ...        ...     ...     ...
# 29542                     18       18         18      18      18
# 29554                     16       16         16      16      16
# 29559                     18       18         18      18      18
# 29575                      9        9          9       9       9
# 29579                     15       15         15      15      15
#
#                sceneXVelocity  sceneYVelocity  sceneXAcceleration  \
# uniqueTrackId
# 18023                      23              23                  23
# 18042                      27              27                  27
# 18053                      25              25                  25
# 18069                      18              18                  18
# 18090                      14              14                  14
# ...                       ...             ...                 ...
# 29542                      18              18                  18
# 29554                      16              16                  16
# 29559                      18              18                  18
# 29575                       9               9                   9
# 29579                      15              15                  15
#
#                sceneYAcceleration
# uniqueTrackId
# 18023                          23
# 18042                          27
# 18053                          25
# 18069                          18
# 18090                          14
# ...                           ...
# 29542                          18
# 29554                          16
# 29559                          18
# 29575                           9
# 29579                          15
#
# [608 rows x 22 columns]

# %%
sceneMeta.head()
# Out:
#    uniqueTrackId  initialFrame  finalFrame  numFrames       class  \
# 0          18023           751         861         23  pedestrian
# 1          18042          1638        1768         27  pedestrian
# 2          18053          2696        2816         25  pedestrian
# 3          18069          4180        4265         18  pedestrian
# 4          18090          5369        5434         14  pedestrian
#
#   horizontalDirection verticalDirection
# 0                EAST             SOUTH
# 1                WEST             NORTH
# 2                EAST             SOUTH
# 3                EAST             SOUTH
# 4                EAST             SOUTH

# %%
sceneMeta.tail()
# Out:
#       uniqueTrackId  initialFrame  finalFrame  numFrames    class  \
# 2207          29545         28580       28785         42  bicycle
# 2208          29569         29651       29821         35  bicycle
# 2209          29588         31323       31548         46  bicycle
# 2210          29590         31352       31572         45  bicycle
# 2211          29593         31526       31726         41  bicycle
#
#      horizontalDirection verticalDirection
# 2207                EAST             SOUTH
# 2208                WEST             NORTH
# 2209                EAST             SOUTH
# 2210                EAST             SOUTH
# 2211                EAST             SOUTH

# %%
visualizer.showLocalTrajectories(pedDf, "uniqueTrackId", "sceneX", "sceneY") 
# Need cleaning. But, first query this pedestrian ids and check what happened. validate these trajectories velocity to ensure they are indeed pedestrians. 
# If they are we need to create another class - horizontal-pedestrians because they might belong to a scenario.

# %%
visualizer.showLocalTrajectories(otherDf, "uniqueTrackId", "sceneX", "sceneY")

# %%
# visualize all peds
from math import ceil
allPedIds = sceneData.uniquePedIds()
limit = 50
nPedIds = len(allPedIds)
nPages = ceil(nPedIds / limit)
for page in range(nPages):
    offset = page * limit
    visualizer.showLocationSceneData(sceneData, onlyClipped=True, showLocal=False, showOthers=False, offset=offset, limit=limit)
# Out:
# 2022-12-10 18:32:02.891 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:03.276 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:03.658 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:04.035 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:04.414 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:04.796 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:05.186 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:05.562 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:05.959 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:06.340 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:06.999 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:07.386 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
# 2022-12-10 18:32:07.783 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png
