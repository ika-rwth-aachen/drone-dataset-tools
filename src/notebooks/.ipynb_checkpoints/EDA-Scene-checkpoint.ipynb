# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"
# dataDir = "E:/Datasets/inD-dataset-v1.0/data/"

# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirE:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tools.TrajectoryUtils import TrajectoryUtils
from tools.TrajectoryVisualizer import TrajectoryVisualizer
import matplotlib.pyplot as plt
import numpy as np
visualizer = TrajectoryVisualizer(None)

# %%
# import pandas as pd
# pedDf = pd.read_csv("../data/location-2/2022-11-19-fps-2.5-scene-31-pedestrians.csv")
# otherDf = pd.read_csv("../data/location-2/2022-11-19-fps-2.5-scene-31-others.csv")
# pedDf.head()

# %%
from extractors.LocationData import LocationData
scene10 = LocationData.load("../data/location-2", "2022-11-19-fps-2.5-scene-11.dll")
# Out:
# 2022-11-30 23:50:11.631 | INFO     | extractors.LocationData:load:463 - reading from ../data/location-2\2022-11-19-fps-2.5-scene-11.dll

# %%
# scene10.backgroundImagePath = "G:AV datasets/inD-dataset-v1.0/data/18_background.png"

# %%
# visualizer.showLocationSceneData(scene10, onlyClipped=True, showOthers=True)
visualizer.showLocationSceneData(scene10, onlyClipped=True)
# Out:
# 2022-11-30 23:51:43.233 | INFO     | tools.TrajectoryVisualizer:initPlot:34 - Loading background image from G:AV datasets/inD-dataset-v1.0/data/18_background.png

# %%
pedDf = scene10.getPedDataInSceneCoordinates()
otherDf = scene10.getOtherDataInSceneCoordinates()
# sceneMeta = scene10.getMeta()

# %%
pedDf.groupby(["uniqueTrackId"]).count()
# Out:
#                index  recordingId  trackId  frame  trackLifetime  xCenter  \
# uniqueTrackId
# 21102             63           63       63     63             63       63
# 23118             16           16       16     16             16       16
# 26255             14           14       14     14             14       14
# 26403              8            8        8      8              8        8
# 27147             13           13       13     13             13       13
# 27159             13           13       13     13             13       13
# 27418             34           34       34     34             34       34
# 27424             23           23       23     23             23       23
# 27426              7            7        7      7              7        7
# 29476             17           17       17     17             17       17
#
#                yCenter  heading  width  length  xVelocity  yVelocity  \
# uniqueTrackId
# 21102               63       63     63      63         63         63
# 23118               16       16     16      16         16         16
# 26255               14       14     14      14         14         14
# 26403                8        8      8       8          8          8
# 27147               13       13     13      13         13         13
# 27159               13       13     13      13         13         13
# 27418               34       34     34      34         34         34
# 27424               23       23     23      23         23         23
# 27426                7        7      7       7          7          7
# 29476               17       17     17      17         17         17
#
#                xAcceleration  yAcceleration  sceneId  roadWidth  sceneX  \
# uniqueTrackId
# 21102                     63             63       63         63      63
# 23118                     16             16       16         16      16
# 26255                     14             14       14         14      14
# 26403                      8              8        8          8       8
# 27147                     13             13       13         13      13
# 27159                     13             13       13         13      13
# 27418                     34             34       34         34      34
# 27424                     23             23       23         23      23
# 27426                      7              7        7          7       7
# 29476                     17             17       17         17      17
#
#                sceneY
# uniqueTrackId
# 21102              63
# 23118              16
# 26255              14
# 26403               8
# 27147              13
# 27159              13
# 27418              34
# 27424              23
# 27426               7
# 29476              17

# %%
sceneMeta.head()
# Out:
#    uniqueTrackId  initialFrame  finalFrame  numFrames       class  \
# 0          18339         22484       22494         15  pedestrian
# 1          18365         24194       24204         19  pedestrian
# 2          19072          4550        4560         23  pedestrian
# 3          19094          6016        6026         20  pedestrian
# 4          20287         17907       17917         19  pedestrian
#
#   horizontalDirection verticalDirection
# 0                WEST             SOUTH
# 1                EAST             NORTH
# 2                WEST             SOUTH
# 3                WEST             SOUTH
# 4                EAST             SOUTH

# %%
sceneMeta.tail()
# Out:
#       uniqueTrackId  initialFrame  finalFrame  numFrames    class  \
# 2310          29537         27915       27925         17  bicycle
# 2311          29563         29411       29421         19  bicycle
# 2312          29565         29357       29367         17  bicycle
# 2313          29571         29698       29708         27  bicycle
# 2314          29583         30869       30879         19  bicycle
#
#      horizontalDirection verticalDirection
# 2310                EAST             SOUTH
# 2311                WEST             NORTH
# 2312                EAST             SOUTH
# 2313                EAST             NORTH
# 2314                EAST             SOUTH

# %%
visualizer.showLocalTrajectories(pedDf, "uniqueTrackId", "sceneX", "sceneY") 
# Need cleaning. But, first query this pedestrian ids and check what happened. validate these trajectories velocity to ensure they are indeed pedestrians. 
# If they are we need to create another class - horizontal-pedestrians because they might belong to a scenario.

# %%
visualizer.showLocalTrajectories(otherDf, "uniqueTrackId", "sceneX", "sceneY")
