# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"
# dataDir = "E:/Datasets/inD-dataset-v1.0/data/"

# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirE:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logging.basicConfig(level=logging.INFO)

from loguru import logger
logger.remove()
logger.add(sys.stdout, format="{level} {message}", filter="my_module", level="INFO")

from extractors.loader import Loader

# %%
loader = Loader(dataDir, 'inD')

# %%
recordingData = loader.getRecordingData('19') 
recordingData.backgroundImagePath
# Out:
# INFO:root:Downsampling recording 19 from 25.0 to 2.5
# downsampling: 100%|█████████████████████████████████████████████████████████| 492008/492008 [00:30<00:00, 16117.96it/s]
# 'G:AV datasets/inD-dataset-v1.0/data/19_background.png'

# %%
recordingData.tracksMetaDf.head()
# Out:
#    recordingId  trackId  initialFrame  finalFrame  numFrames    width  \
# 0           19        0             0         105        106  1.97574
# 1           19        1             0          65         66  1.86671
# 2           19        2             0         341        342  0.00000
# 3           19        3             0       24835      24836  2.06339
# 4           19        4             0       24835      24836  1.82690
#
#     length       class crossing turn onStreet
# 0  4.73697         car       no   no       no
# 1  4.55969         car       no   no       no
# 2  0.00000  pedestrian       no  yes       no
# 3  4.50165         car       no   no       no
# 4  4.24700         car       no   no       no

# %%
recordingData.tracksMetaDf["class"].unique()
# Out:
# array(['car', 'pedestrian', 'bicycle', 'truck_bus'], dtype=object)

# %%
# recordingData.getCarIds()

# %%
# recordingData.getLargeVehicleIds()

# %%
# recordingData.getBicycleIds()

# %%
# recordingData.getPedIds()

# %%
# recordingData.getVehicleIds()

# %%
# frameDf = recordingData.getDfByFrameSpan(0, 0)

# %%
# len(frameDf)

# %%
# recordingData.getDfById(41)

# %%
from tools.UnitUtils import UnitUtils
allLocationSceneConfig = UnitUtils.loadSceneConfiguration()
sceneConfigs = allLocationSceneConfig['2']
sceneId = 10
sC = sceneConfigs[str(sceneId)]
print(sC)
sceneData = recordingData.getSceneData(sceneId, sC, refresh=True)
# Out:
# {'centerXPixel': 628.5, 'centerYPixel': 286.5, 'centerX': 61.44, 'centerY': -28.01, 'angle': 12.17, 'roadWidth': 5.0, 'boxWidth': 10.0}
# recording-19-scene10-ped: 100%|██████████████████████████████████████████████████████| 122/122 [00:01<00:00, 68.19it/s]
# recording-19-scene10-car-Ids: 100%|██████████████████████████████████████████████████| 151/151 [00:04<00:00, 33.02it/s]
# recording-19-scene10-bicycle-Ids: 100%|████████████████████████████████████████████████| 92/92 [00:01<00:00, 83.78it/s]
# recording-19-scene10-truck_bus-Ids: 100%|████████████████████████████████████████████████| 5/5 [00:00<00:00, 94.34it/s]
# clipping ped trajectories for scene # 10 with width offset 4.0: 100%|██████████████████| 36/36 [00:00<00:00, 98.90it/s]
# clipping other trajectories for scene # 10: 100%|██████████████████████████████████████| 91/91 [00:01<00:00, 89.65it/s]
# INFO:root:adding pedestrian local dynamics for scene 10
# deriving velocity on sceneX at fps 2.5: 100%|█████████████████████████████████████████| 35/35 [00:00<00:00, 442.87it/s]
# deriving velocity on sceneY at fps 2.5: 100%|█████████████████████████████████████████| 35/35 [00:00<00:00, 437.49it/s]
# deriving acceleration on sceneXVelocity at fps 2.5: 100%|█████████████████████████████| 35/35 [00:00<00:00, 430.28it/s]
# deriving acceleration on sceneYVelocity at fps 2.5: 100%|█████████████████████████████| 35/35 [00:00<00:00, 432.10it/s]
# INFO:root:adding other local dynamics for scene 10
# deriving velocity on sceneX at fps 2.5: 100%|█████████████████████████████████████████| 91/91 [00:00<00:00, 356.86it/s]
# deriving velocity on sceneY at fps 2.5: 100%|█████████████████████████████████████████| 91/91 [00:00<00:00, 361.07it/s]
# deriving acceleration on sceneXVelocity at fps 2.5: 100%|█████████████████████████████| 91/91 [00:00<00:00, 355.47it/s]
# deriving acceleration on sceneYVelocity at fps 2.5: 100%|█████████████████████████████| 91/91 [00:00<00:00, 350.00it/s]
# INFO:root:trimming pedestrian local data for scene 10
# trimming trajectories: 100%|██████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 897.48it/s]
# INFO:root:trimming other local data for scene 10
# trimming trajectories: 100%|██████████████████████████████████████████████████████████| 91/91 [00:00<00:00, 858.49it/s]
# clipping ped trajectories for scene # 10 with width offset 0.0: 100%|█████████████████| 36/36 [00:00<00:00, 113.92it/s]
# 19040 8
# 19045 16
# 19047 20
# 19049 4
# 19055 24
# 19057 13
# 19059 14
# 19060 14
# 19063 3
# 19070 12
# 19071 14
# 19132 11
# 19133 18
# 19140 15
# 19147 10
# 19149 8
# 19150 19
# 19153 21
# 19178 12
# 19180 12
# 19199 12
# 19205 14
# 19212 19
# 19214 20
# 19235 15
# 19242 14
# 19243 10
# 19283 15
# 19289 16
# 19293 15
# 19295 13
# 19320 13
# 19337 12
# 19346 15
# 19349 16
# 19016 12
# 19018 19
# 19021 10
# 19028 12
# 19032 17
# 19043 18
# 19044 54
# 19052 19
# 19054 30
# 19058 24
# 19064 16
# 19073 14
# 19078 61
# 19083 17
# 19089 15
# 19092 14
# 19095 19
# 19105 22
# 19113 13
# 19114 18
# 19118 20
# 19119 17
# 19124 42
# 19137 30
# 19139 27
# 19144 32
# 19151 32
# 19152 26
# 19170 18
# 19173 23
# 19174 17
# 19179 31
# 19184 16
# 19189 12
# 19193 11
# 19200 19
# 19201 33
# 19202 33
# 19213 21
# 19220 26
# 19221 28
# 19228 24
# 19241 44
# 19248 16
# 19257 20
# 19258 17
# 19259 17
# 19266 14
# 19277 16
# 19279 19
# 19284 19
# 19290 11
# 19292 11
# 19297 15
# 19298 22
# 19300 72
# 19301 17
# 19303 17
# 19306 17
# 19309 31
# 19314 46
# 19326 23
# 19328 23
# 19334 21
# 19344 13
# 19357 15
# 19358 16
# 19361 10
# 19366 19
# 19068 13
# 19069 68
# 19076 18
# 19082 13
# 19097 15
# 19108 14
# 19109 43
# 19143 33
# 19146 25
# 19156 23
# 19176 19
# 19195 10
# 19246 7
# 19256 18
# 19261 16
# 19262 90
# 19263 90
# 19278 49
# 19299 21
# 19322 26
# 19323 32
# 19210 18

# %%
pedDf = sceneData.getPedDataInSceneCoordinates()
pedDf.head()
# Out:
#    recordingId  trackId  frame  trackLifetime   xCenter   yCenter    heading  \
# 2           19       40   1999            110  65.38982 -29.74168  123.24568
# 3           19       40   2009            120  64.92454 -28.94136  122.66286
# 4           19       40   2019            130  64.41796 -28.11242  123.32692
# 5           19       40   2029            140  63.89306 -27.29404  125.21769
# 6           19       40   2039            150  63.34764 -26.51882  128.25877
#
#    width  length  xVelocity  ...  yAcceleration  uniqueTrackId  sceneId  \
# 2    0.0     0.0   -1.20167  ...        0.28879          19040       10
# 3    0.0     0.0   -1.21674  ...        0.14726          19040       10
# 4    0.0     0.0   -1.27560  ...       -0.06193          19040       10
# 5    0.0     0.0   -1.33738  ...       -0.22881          19040       10
# 6    0.0     0.0   -1.40034  ...       -0.31349          19040       10
#
#    roadWidth    sceneX    sceneY  sceneXVelocity  sceneYVelocity  \
# 2        5.0  3.495993 -2.525436        0.836094       -2.078956
# 3        5.0  3.209887 -1.645015        0.715264       -2.201053
# 4        5.0  2.889443 -0.727911        0.801110       -2.292761
# 5        5.0  2.548865  0.182733        0.851446       -2.276610
# 6        5.0  2.179129  1.055513        0.924340       -2.181949
#
#    sceneXAcceleration  sceneYAcceleration
# 2            0.284845            0.218230
# 3            0.302075            0.305241
# 4           -0.214615            0.229271
# 5           -0.125840           -0.040379
# 6           -0.182235           -0.236651
#
# [5 rows x 22 columns]

# %%
otherDf = sceneData.getOtherDataInSceneCoordinates()
otherDf.head()
# Out:
#    recordingId  trackId  frame  trackLifetime   xCenter   yCenter   heading  \
# 2           19       16    302             70  38.27716 -32.99946  10.65386
# 3           19       16    312             80  41.06384 -32.51196  10.82879
# 4           19       16    322             90  43.96534 -31.99766  10.98268
# 5           19       16    332            100  47.10503 -31.43942  10.76852
# 6           19       16    342            110  50.52537 -30.82353  10.62953
#
#      width   length  xVelocity  ...  uniqueTrackId  sceneId  roadWidth  class  \
# 2  2.06353  5.15411    6.91869  ...          19016       10        5.0    car
# 3  2.06353  5.15411    7.07186  ...          19016       10        5.0    car
# 4  2.06353  5.15411    7.52231  ...          19016       10        5.0    car
# 5  2.06353  5.15411    8.17264  ...          19016       10        5.0    car
# 6  2.06353  5.15411    8.93215  ...          19016       10        5.0    car
#
#       sceneX    sceneY sceneXVelocity  sceneYVelocity  sceneXAcceleration  \
# 2 -23.694131  0.005699      -7.067459        0.267166           -0.437622
# 3 -20.867306 -0.105226      -7.067062        0.277311           -0.000994
# 4 -17.922592 -0.214158      -7.361785        0.272330            0.736809
# 5 -14.735778 -0.330351      -7.967035        0.290483            1.513126
# 6 -11.262468 -0.449354      -8.683276        0.297508            1.790601
#
#    sceneYAcceleration
# 2           -0.330739
# 3           -0.025360
# 4            0.012451
# 5           -0.045381
# 6           -0.017564
#
# [5 rows x 23 columns]

# %%
# other = otherDf[otherDf["uniqueTrackId"]==19108]
# other

# %%
# otherFull = sceneData.otherData[sceneData.otherData["uniqueTrackId"] == 19108]
# otherFull

# %%
scenePolygon = TrajectoryUtils.scenePolygon(
    sceneData.sceneConfig, sceneData.sceneConfig["boxWidth"] + 50, sceneData.sceneConfig["roadWidth"] + 10)

clippedDf = TrajectoryUtils.clipByRect(
    otherFull, "xCenter", "yCenter", "frame", scenePolygon)

if TrajectoryUtils.length(clippedDf, "xCenter", "yCenter") < sceneData.sceneConfig["roadWidth"]:
    logger.debug(
        f"Disregarding trajectory for {otherId} because the length is too low")
clippedDf

# %%
from tools.TrajectoryUtils import TrajectoryUtils
from tools.TrajectoryVisualizer import TrajectoryVisualizer
import matplotlib.pyplot as plt
import numpy as np
visualizer = TrajectoryVisualizer(loader)

# %%
# visualizer.showLocationSceneData(sceneData, onlyClipped=True, showOthers=True)
visualizer.showLocationSceneData(sceneData, onlyClipped=True, showOthers=True, ids=[19108])

# %%
localMeta = sceneData.getMeta()

# %%
localMeta
# Out:
#      uniqueTrackId  initialFrame  finalFrame  numFrames       class  \
# 0            19040          1999        2009          8  pedestrian
# 1            19045          2779        2789         16  pedestrian
# 2            19047          2766        2776         20  pedestrian
# 3            19049          2604        2614          4  pedestrian
# 4            19055          2728        2738         24  pedestrian
# ..             ...           ...         ...        ...         ...
# 121          19278         19784       19794         49     bicycle
# 122          19299         20818       20828         21     bicycle
# 123          19322         22144       22154         26     bicycle
# 124          19323         22184       22194         32     bicycle
# 125          19210         15330       15340         18   truck_bus
#
#     horizontalDirection verticalDirection
# 0                  WEST             NORTH
# 1                  EAST             SOUTH
# 2                  EAST             SOUTH
# 3                  EAST             SOUTH
# 4                  EAST             SOUTH
# ..                  ...               ...
# 121                EAST             SOUTH
# 122                EAST             SOUTH
# 123                EAST             SOUTH
# 124                EAST             SOUTH
# 125                EAST             SOUTH
#
# [126 rows x 7 columns]

# %%
visualizer.showLocationSceneData(sceneData, onlyClipped=True)

# %%
pedDf = sceneData.getPedDataInSceneCoordinates()
visualizer.showLocalTrajectories(pedDf, "uniqueTrackId", "sceneX", "sceneY")
