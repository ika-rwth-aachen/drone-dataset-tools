# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"
dataDir = "E:/Datasets/inD-dataset-v1.0/data/"

# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirD:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logging.basicConfig(level=logging.INFO)

from loguru import logger
logger.remove()
logger.add(sys.stdout, format="{level} {message}", filter="my_module", level="INFO")

from extractors.loader import Loader

# %%
loader = Loader(dataDir, 'inD')

# %%
recordingData = loader.getRecordingData('19') 
recordingData.backgroundImagePath
# Out:
# INFO:root:Downsampling recording 19 from 25.0 to 2.5
# downsampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 492008/492008 [00:20<00:00, 23947.74it/s]
# 'E:/Datasets/inD-dataset-v1.0/data/19_background.png'

# %%
recordingData.tracksMetaDf.head()
# Out:
#    recordingId  trackId  initialFrame  finalFrame  numFrames    width  \
# 0           19        0             0         105        106  1.97574
# 1           19        1             0          65         66  1.86671
# 2           19        2             0         341        342  0.00000
# 3           19        3             0       24835      24836  2.06339
# 4           19        4             0       24835      24836  1.82690
#
#     length       class crossing turn onStreet
# 0  4.73697         car       no   no       no
# 1  4.55969         car       no   no       no
# 2  0.00000  pedestrian       no  yes       no
# 3  4.50165         car       no   no       no
# 4  4.24700         car       no   no       no

# %%
recordingData.tracksMetaDf["class"].unique()
# Out:
# array(['car', 'pedestrian', 'bicycle', 'truck_bus'], dtype=object)

# %%
# recordingData.getCarIds()

# %%
# recordingData.getLargeVehicleIds()

# %%
# recordingData.getBicycleIds()

# %%
# recordingData.getPedIds()

# %%
# recordingData.getVehicleIds()

# %%
# frameDf = recordingData.getDfByFrameSpan(0, 0)

# %%
# len(frameDf)

# %%
# recordingData.getDfById(41)

# %%
from tools.UnitUtils import UnitUtils
allLocationSceneConfig = UnitUtils.loadSceneConfiguration()
sceneConfigs = allLocationSceneConfig['2']
sceneId = 22
sC = sceneConfigs[str(sceneId)]
print(sC)
sceneData = recordingData.getSceneData(sceneId, sC, refresh=True)
# Out:
# {'centerXPixel': 188.5, 'centerYPixel': 375.5, 'centerX': 18.43, 'centerY': -36.71, 'angle': 16.0, 'roadWidth': 9.0, 'boxWidth': 20.0}
# recording-19-scene22-ped: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 122/122 [00:01<00:00, 86.58it/s]
# recording-19-scene22-car-Ids: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 151/151 [00:02<00:00, 50.53it/s]
# recording-19-scene22-bicycle-Ids: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 92/92 [00:00<00:00, 95.94it/s]
# recording-19-scene22-truck_bus-Ids: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 104.10it/s]
# clipping ped trajectories for scene # 22: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 135.03it/s]
# clipping other trajectories for scene # 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 127/127 [00:00<00:00, 143.65it/s]
# INFO:root:adding pedestrian local dynamics for scene 22
# deriving velocity on sceneX at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 363.59it/s]
# deriving velocity on sceneY at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 362.79it/s]
# deriving acceleration on sceneXVelocity at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 399.97it/s]
# deriving acceleration on sceneYVelocity at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 398.80it/s]
# INFO:root:adding other local dynamics for scene 22
# deriving velocity on sceneX at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:00<00:00, 468.39it/s]
# deriving velocity on sceneY at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:00<00:00, 482.54it/s]
# deriving acceleration on sceneXVelocity at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:00<00:00, 467.79it/s]
# deriving acceleration on sceneYVelocity at fps 2.5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:00<00:00, 468.34it/s]
# INFO:root:trimming pedestrian local data for scene 22
# trimming trajectories: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 666.69it/s]
# INFO:root:trimming other local data for scene 22
# trimming trajectories: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:00<00:00, 828.93it/s]

# %%
sceneData.locationId
# Out:
# 2

# %%
crossingDf = sceneData.getPedDataInSceneCorrdinates()
crossingDf.head()
# Out:
#    recordingId  trackId  frame  trackLifetime   xCenter   yCenter    heading  \
# 1           19       72   4550            350  25.99944 -30.29269   242.4037
# 2           19       72   4560            360  25.84202 -30.58483  246.08436
# 3           19       72   4570            370  25.74525 -30.86465  249.51171
# 4           19       72   4580            380  25.66758 -31.18894  252.38229
# 5           19       72   4590            390  25.56239 -31.55764  254.60277
#
#    width  length  xVelocity  ...  yAcceleration  uniqueTrackId  sceneId  \
# 1    0.0     0.0   -0.44166  ...        0.12559          19072       22
# 2    0.0     0.0   -0.30992  ...       -0.00132          19072       22
# 3    0.0     0.0   -0.21941  ...       -0.19737          19072       22
# 4    0.0     0.0   -0.22207  ...       -0.30787          19072       22
# 5    0.0     0.0   -0.26032  ...        -0.3427          19072       22
#
#    roadWidth    sceneX    sceneY  sceneXVelocity  sceneYVelocity  \
# 1        9.0  9.045063  4.082294        0.688759        0.625742
# 2        9.0  8.813217  3.844862        0.579616        0.593580
# 3        9.0  8.643066  3.602555        0.425375        0.605767
# 4        9.0  8.479019  3.312236        0.410119        0.725797
# 5        9.0  8.276276  2.986813        0.506857        0.813557
#
#    sceneXAcceleration  sceneYAcceleration
# 1            0.000000            0.000000
# 2            0.272858            0.080405
# 3            0.385602           -0.030467
# 4            0.038141           -0.300075
# 5           -0.241844           -0.219401
#
# [5 rows x 22 columns]

# %%
sceneData.uniquePedIds()
# Out:
# array([19072, 19075, 19081, 19125, 19343], dtype=int64)

# %%
sceneData.uniqueOtherIds()
# Out:
# array([19016, 19018, 19023, 19025, 19028, 19036, 19043, 19048, 19052,
#        19061, 19064, 19067, 19073, 19077, 19079, 19083, 19085, 19089,
#        19092, 19095, 19106, 19111, 19116, 19118, 19119, 19120, 19129,
#        19130, 19131, 19137, 19139, 19144, 19151, 19154, 19164, 19165,
#        19172, 19179, 19181, 19184, 19191, 19193, 19200, 19213, 19216,
#        19218, 19227, 19228, 19229, 19231, 19239, 19248, 19257, 19258,
#        19259, 19266, 19268, 19270, 19279, 19284, 19285, 19286, 19287,
#        19290, 19292, 19298, 19301, 19303, 19306, 19308, 19317, 19324,
#        19326, 19328, 19332, 19344, 19348, 19359, 19361, 19027, 19062,
#        19065, 19076, 19080, 19087, 19097, 19100, 19122, 19123, 19127,
#        19134, 19136, 19142, 19143, 19155, 19156, 19162, 19169, 19171,
#        19182, 19185, 19186, 19192, 19195, 19206, 19208, 19234, 19245,
#        19250, 19254, 19256, 19262, 19269, 19272, 19299, 19305, 19307,
#        19330, 19333, 19342, 19345, 19347, 19351, 19354, 19355, 19367,
#        19217, 19273], dtype=int64)

# %%
# otherDf = sceneData.otherData
# otherDf.head()

# %%
otherDf = sceneData.getOtherDataInSceneCorrdinates()
otherDf.head()
# Out:
#    recordingId  trackId  frame  trackLifetime   xCenter   yCenter   heading  \
# 0           19       16    232              0   14.9355 -38.28918  13.93677
# 1           19       16    242             10  18.77482 -37.32848  14.74359
# 2           19       16    252             20  22.58134 -36.37444  14.42102
# 3           19       16    262             30  26.19275 -35.48898   13.7152
# 4           19       16    272             40  29.54836 -34.72084  13.10055
#
#      width   length  xVelocity  ...  uniqueTrackId  sceneId  roadWidth  class  \
# 0  2.06353  5.15411    9.45846  ...          19016       22        9.0    car
# 1  2.06353  5.15411    9.58676  ...          19016       22        9.0    car
# 2  2.06353  5.15411    9.29739  ...          19016       22        9.0    car
# 3  2.06353  5.15411    8.72813  ...          19016       22        9.0    car
# 4  2.06353  5.15411    8.05783  ...          19016       22        9.0    car
#
#       sceneX    sceneY sceneXVelocity  sceneYVelocity  sceneXAcceleration  \
# 0  -3.794410 -0.554791      -9.888490        0.336940            0.000000
# 1   0.160986 -0.689566      -9.888490        0.336940            0.000000
# 2   4.083017 -0.821703      -9.805077        0.330342           -0.208532
# 3   7.798593 -0.965984      -9.288940        0.360702           -1.290344
# 4  11.235940 -1.152532      -8.593369        0.466370           -1.738928
#
#    sceneYAcceleration
# 0            0.000000
# 1            0.000000
# 2            0.016493
# 3           -0.075898
# 4           -0.264170
#
# [5 rows x 23 columns]

# %%
otherDf["class"][0]
# Out:
# 'car'

# %%
from tools.TrajectoryUtils import TrajectoryUtils
from tools.TrajectoryVisualizer import TrajectoryVisualizer
import matplotlib.pyplot as plt
import numpy as np
visualizer = TrajectoryVisualizer(loader)

# %%
# visualizer.showLocationSceneData(sceneData, onlyClipped=True, showOthers=True)
visualizer.showLocationSceneData(sceneData, onlyClipped=True, showOthers=False)

# %%
localDf = sceneData.getPedDataInSceneCorrdinates()

# %%
localDf.head()
# Out:
#    recordingId  trackId  frame  trackLifetime   xCenter   yCenter    heading  \
# 0           19       72   4540            340  26.19528 -29.97615  238.77605
# 1           19       72   4550            350  25.99944 -30.29269   242.4037
# 2           19       72   4560            360  25.84202 -30.58483  246.08436
# 3           19       72   4570            370  25.74525 -30.86465  249.51171
# 4           19       72   4580            380  25.66758 -31.18894  252.38229
#
#    width  length  xVelocity  ...  yAcceleration  uniqueTrackId  sceneId  \
# 0    0.0     0.0   -0.52503  ...         0.1434          19072       22
# 1    0.0     0.0   -0.44166  ...        0.12559          19072       22
# 2    0.0     0.0   -0.30992  ...       -0.00132          19072       22
# 3    0.0     0.0   -0.21941  ...       -0.19737          19072       22
# 4    0.0     0.0   -0.22207  ...       -0.30787          19072       22
#
#    roadWidth    sceneX    sceneY  sceneXVelocity  sceneYVelocity  \
# 0        9.0  9.320567  4.332591        0.688759        0.625742
# 1        9.0  9.045063  4.082294        0.688759        0.625742
# 2        9.0  8.813217  3.844862        0.579616        0.593580
# 3        9.0  8.643066  3.602555        0.425375        0.605767
# 4        9.0  8.479019  3.312236        0.410119        0.725797
#
#    sceneXAcceleration  sceneYAcceleration
# 0            0.000000            0.000000
# 1            0.000000            0.000000
# 2            0.272858            0.080405
# 3            0.385602           -0.030467
# 4            0.038141           -0.300075
#
# [5 rows x 22 columns]

# %%
localMeta = sceneData.getMeta()

# %%
localMeta
# Out:
#      uniqueTrackId  initialFrame  finalFrame  numFrames       class  \
# 0            19072        4540.0      4550.0         23  pedestrian
# 1            19075        4425.0      4435.0         26  pedestrian
# 2            19125        8342.0      8352.0         10  pedestrian
# 3            19343       23440.0     23450.0         25  pedestrian
# 4            19016         232.0       242.0         13         car
# ..             ...           ...         ...        ...         ...
# 125          19351       23705.0     23715.0         23     bicycle
# 126          19354       24090.0     24100.0         15     bicycle
# 127          19355       24103.0     24113.0         16     bicycle
# 128          19367       24655.0     24665.0         15     bicycle
# 129          19273       19614.0     19624.0         10   truck_bus
#
#      horizontalDirection     verticalDirection
# 0    TrackDirection.WEST  TrackDirection.SOUTH
# 1    TrackDirection.EAST  TrackDirection.SOUTH
# 2    TrackDirection.WEST  TrackDirection.SOUTH
# 3    TrackDirection.WEST  TrackDirection.SOUTH
# 4    TrackDirection.EAST  TrackDirection.SOUTH
# ..                   ...                   ...
# 125  TrackDirection.EAST  TrackDirection.SOUTH
# 126  TrackDirection.EAST  TrackDirection.SOUTH
# 127  TrackDirection.EAST  TrackDirection.SOUTH
# 128  TrackDirection.EAST  TrackDirection.SOUTH
# 129  TrackDirection.WEST  TrackDirection.NORTH
#
# [130 rows x 7 columns]

# %%
sceneData.uniquePedIds()
# Out:
# <IntegerArray>
# [19072, 19075, 19081, 19125, 19343]
# Length: 5, dtype: Int64

# %%
visualizer.showLocationSceneData(sceneData, onlyClipped=True)

# %%
from tools.TrajectoryUtils import TrajectoryUtils
trimmedLocalDf = TrajectoryUtils.trimHeadAndTailForAll(localDf)
# Out:
# trimming trajectories: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 666.69it/s]

# %%
len(trimmedLocalDf)
# Out:
# 76

# %%
len(localDf)
# Out:
# 84
