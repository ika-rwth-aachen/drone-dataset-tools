# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
dataDir = "G:AV datasets/inD-dataset-v1.0/data/"
# dataDir = "E:/Datasets/inD-dataset-v1.0/data/"

# %%
exec(open('init_notebook.py').read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7fe12250716c> in <module>
# ----> 1 exec(open('init_notebook.py').read())
#
# <string> in <module>
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:/AV/DataSetExploration/drone-dataset-tools/src'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from extractors.loader import Loader
loader = Loader(dataDir, 'inD')

# %%
from extractors.LocationData import LocationData
loc2data = LocationData.load("../data/location-2")
# Out:
# 2022-09-30 14:12:56.490 | INFO     | extractors.LocationData:load:301 - reading from ../data/location-2\all.dill

# %%
from tools.TrajectoryUtils import TrajectoryUtils
from tools.TrajectoryVisualizer import TrajectoryVisualizer
import matplotlib.pyplot as plt
import numpy as np
visualizer = TrajectoryVisualizer(loader)

# %%
scene20Data = loc2data.getSceneCrossingData(20, 10, 6, refresh=False)
visualizer.showLocationSceneData(scene20Data)

scene21Data = loc2data.getSceneCrossingData(21, 20, 9, refresh=False)
visualizer.showLocationSceneData(scene21Data, onlyClipped=False)

scene22Data = loc2data.getSceneCrossingData(22, 10, 6, refresh=False)
visualizer.showLocationSceneData(scene22Data)
# Out:
# 2022-09-30 14:12:59.470 | INFO     | tools.TrajectoryVisualizer:initPlot:29 - Loading background image from E:/Datasets/inD-dataset-v1.0/data/18_background.png
# 2022-09-30 14:13:09.135 | INFO     | tools.TrajectoryVisualizer:initPlot:29 - Loading background image from E:/Datasets/inD-dataset-v1.0/data/18_background.png
# 2022-09-30 14:13:10.683 | INFO     | tools.TrajectoryVisualizer:initPlot:29 - Loading background image from E:/Datasets/inD-dataset-v1.0/data/18_background.png

# %%
transformerData = loc2data.getCrossingDataForTransformer()
# Out:
# merging scenes: 100%|██████████| 3/3 [00:00<00:00, 93.75it/s]

# %%
transformerData.keys()
# Out:
# dict_keys([5.0, 6.0, 9.0])

# %%
transformerData["5.0"].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 transformerData["5.0"].head()
#
# KeyError: '5.0'

# %%
# Out:
# dict_keys([])
