# %% [markdown]
# # TO RUN
# 1. Make sure you installed all the dependencies
# 2. open **'init_notebook.py'** and change the **projectFolder** to the src folder of the repository.
# 3. In the following cell change the dataDir to the data directory of the InD dataset

# %%
exec(open('init_notebook.py').read())
# Out:
# current working dirE:\AV\DataSetExploration\drone-dataset-tools\src

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# import logging
# logging.basicConfig(level=logging.INFO)
# from loguru import logger
# logger.remove()
# logger.add(sys.stdout, format="{level} {message}", filter="my_module", level="INFO")

# %%
# Unit tests on preprocessed scene data of location 2

# %%
from extractors.LocationData import LocationData
scene10 = LocationData.load("../data/location-2", "2022-11-13-fps-2.5-scene-10.dll")

# %%
allPedDfs = scene10.getClippedPedDfs()
otherDfs = scene10.getClippedOtherDfs()
allPedIds = scene10.uniqueClippedPedIds()
allOtherIds = scene10.uniqueClippedOtherIds()

# pedClasses = allPedDfs['class'].unique()
otherClasses = otherDfs['class'].unique()

# %%
assert len(otherClasses) > 1
assert 'pedestrian' not in otherClasses

# %%
assert allPedIds == allPedDfs["uniqueTrackId"].unique()
assert allOtherIds == otherDfs["uniqueTrackId"].unique()

# %%
primaryPedId = allPedIds[0]
primaryDf = scene10.getClippedPedDfByUniqueTrackId(primaryPedId).copy()
primaryPedId
# Out:
# 18023

# %%
from extractors.PedScenarioBuilder import PedScenarioBuilder
scenarioBuilder = PedScenarioBuilder()

# %%
recordingId, start, end, roadWidth = scenarioBuilder.getRecordStartEndWidth(primaryDf)

# %%
assert primaryDf["frame"].min() == start
assert primaryDf["frame"].max() == end
assert len(primaryDf["recordingId"].unique()) == 1
assert primaryDf["recordingId"].unique()[0] == recordingId
assert len(primaryDf["roadWidth"].unique()) == 1
assert primaryDf["roadWidth"].unique()[-1] == roadWidth

# %%
anotherDf = otherDfs[otherDfs['uniqueTrackId'] == allOtherIds[0]]
scenarioBuilder.getOtherType(anotherDf)
# Out:
# 'car'

# %%
interestingPedIds = [18107, 18112, 18121, 18127, 18134]
# 18107, 18112, 18121, 18134 has  2
# 18127 has 3
scenePeds = {}

scenePeds[18107] = [18112, 18121] #6343, 7183
scenePeds[18112] = [18107, 18121]
scenePeds[18121] = [18112, 18127]
scenePeds[18127] = [18127, 18134, 18156]
scenePeds[18121] = [18112, 18127]
scenePeds[18134] = [18127, 18156]

# %%
scenarioBuilder.printSceneStats(scene10)
# Out:
# recordingId, primaryPedId,  start, end, roadWidth  18 18023 286 1076 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18042 1363 2423 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18053 2186 3076 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18069 3640 4490 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18090 4969 5589 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18107 6343 7183 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18112 6579 7189 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18121 6977 7727 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18127 7466 9506 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18134 7951 9521 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18156 9264 9574 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18162 9848 10728 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18166 9984 10494 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18168 10043 11303 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18180 11464 12134 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18181 11507 12247 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18201 13019 13629 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18204 13127 13747 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18214 13890 14480 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18225 14626 16016 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18248 15734 16564 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18273 18204 18754 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18279 18495 19295 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18280 18531 19341 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18281 18533 19303 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18298 19906 20716 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18304 20248 20858 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18306 20267 20967 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18311 20546 21136 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18319 20809 21519 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18322 20933 21583 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18337 21994 22464 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18344 22723 24323 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18382 24937 25667 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 18388 25415 26975 5.0
# recordingId, primaryPedId,  start, end, roadWidth  18 
5.0
# recordingId, primaryPedId,  start, end, roadWidth  29 29575 30134 30804 5.0
# recordingId, primaryPedId,  start, end, roadWidth  29 29579 30276 31486 5.0

# %%
primaryDf["uniqueTrackId"]
# Out:
# 426    18107
# 427    18107
# 428    18107
# 429    18107
# 430    18107
#        ...
# 506    18107
# 507    18107
# 508    18107
# 509    18107
# 510    18107
# Name: uniqueTrackId, Length: 85, dtype: Int64

# %%
primaryDf["uniqueTrackId"].iat[0]
# Out:
# 18107

# %%
for primaryPedId in interestingPedIds:
    primaryDf = scene10.getPedDfByUniqueTrackId(primaryPedId).copy()
    recordingId, start, end, roadWidth = scenarioBuilder.getRecordStartEndWidth(primaryDf)
    scenarioPedTracks = scenarioBuilder.getOtherPedScenarioTracksFromScene(
        primaryDf = primaryDf,
        allPedDfs=allPedDfs,
        recordingId = recordingId,
        start=start,
        end=end
    )
    print("primaryPedId", primaryPedId)
    print(scenePeds[primaryPedId])
    print(scenarioPedTracks["uniqueTrackId"].unique())
    assert scenarioPedTracks["uniqueTrackId"].unique() == scenePeds[primaryPedId];
    assert len(scenarioPedTracks["uniqueTrackId"].unique()) == len(scenePeds[primaryPedId]);
# Out:
# pedestrian with (18, 6343, 7183) <IntegerArray>
# [18107, 18112]
# Length: 2, dtype: Int64
# primaryPedId 18107
# [18112, 18121]
# <IntegerArray>
# [18112]
# Length: 1, dtype: Int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-cb932e1b5d4f> in <module>
#      12     print(scenePeds[primaryPedId])
#      13     print(scenarioPedTracks["uniqueTrackId"].unique())
# ---> 14     assert scenarioPedTracks["uniqueTrackId"].unique() == scenePeds[primaryPedId];
#      15     assert len(scenarioPedTracks["uniqueTrackId"].unique()) == len(scenePeds[primaryPedId]);
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\.conda\envs\drone\lib\site-packages\pandas\core\arrays\integer.py in cmp_method(self, other)
#     528                     )
#     529                 if len(self) != len(other):
# --> 530                     raise ValueError("Lengths must match to compare")
#     531
#     532             if other is libmissing.NA:
#
# ValueError: Lengths must match to compare

# %%
scenarioPedTracks
# Out:
#      index  recordingId  trackId  frame  trackLifetime   xCenter   yCenter  \
# 93     513           18      112   6599             20  62.22064 -31.03361
# 94     514           18      112   6609             30  61.94295 -30.47937
# 95     515           18      112   6619             40  61.69207 -29.92048
# 96     516           18      112   6629             50  61.48509 -29.37109
# 97     517           18      112   6639             60  61.31123 -28.83789
# 98     518           18      112   6649             70  61.15505 -28.32089
# 99     519           18      112   6659             80  61.00643 -27.79699
# 100    520           18      112   6669             90  60.84336 -27.26863
# 101    521           18      112   6679            100  60.66139 -26.74464
# 102    522           18      112   6689            110  60.47063 -26.23477
# 103    523           18      112   6699            120  60.28338 -25.75053
# 104    524           18      112   6709            130  60.11038 -25.30000
# 105    525           18      112   6719            140  59.94410 -24.89697
# 106    526           18      112   6729            150  59.76188 -24.52985
#
#        heading  width  length  xVelocity  yVelocity  xAcceleration  \
# 93   117.96779    0.0     0.0   -0.71909    1.35775        0.11330
# 94   115.91950    0.0     0.0   -0.66383    1.39796        0.18219
# 95   113.72179    0.0     0.0   -0.57126    1.39010        0.22962
# 96   111.67643    0.0     0.0   -0.47451    1.35356        0.19481
# 97   110.03755    0.0     0.0   -0.40733    1.30892        0.11443
# 98   108.96717    0.0     0.0   -0.37566    1.29945        0.02366
# 99   108.50592    0.0     0.0   -0.38821    1.31897       -0.06568
# 100  108.63986    0.0     0.0   -0.43162    1.31753       -0.08998
# 101  109.27366    0.0     0.0   -0.46712    1.29592       -0.04628
# 102  110.32586    0.0     0.0   -0.47331    1.24615        0.01884
# 103  111.71976    0.0     0.0   -0.45070    1.16810        0.05490
# 104  113.38288    0.0     0.0   -0.42330    1.06433        0.01632
# 105  115.23247    0.0     0.0   -0.43366    0.95415       -0.05005
# 106  117.17946    0.0     0.0   -0.46383    0.92777       -0.05371
#
#      yAcceleration  uniqueTrackId sceneId  roadWidth    sceneX    sceneY
# 93         0.12885          18112      10        5.0  0.125680 -3.120228
# 94         0.03424          18112      10        5.0 -0.028928 -2.519903
# 95        -0.05099          18112      10        5.0 -0.156349 -1.920684
# 96        -0.08961          18112      10        5.0 -0.242859 -1.340007
# 97        -0.06215          18112      10        5.0 -0.300406 -0.782138
# 98         0.00796          18112      10        5.0 -0.344086 -0.243832
# 99         0.01244          18112      10        5.0 -0.378921  0.299625
# 100       -0.03241          18112      10        5.0 -0.426941  0.850488
# 101       -0.09351          18112      10        5.0 -0.494358  1.401064
# 102       -0.16180          18112      10        5.0 -0.573343  1.939690
# 103       -0.22192          18112      10        5.0 -0.654301  2.452522
# 104       -0.25096          18112      10        5.0 -0.728435  2.929398
# 105       -0.15788          18112      10        5.0 -0.806015  3.358424
# 106        0.01318          18112      10        5.0 -0.906746  3.755708

# %%
primaryPedId = 18121

primaryDf = scene10.getPedDfByUniqueTrackId(primaryPedId).copy()
recordingId, start, end, roadWidth = scenarioBuilder.getRecordStartEndWidth(primaryDf)
recordingId, start, end, roadWidth
# Out:
# (18, 6977, 7727, 5.0)

# %%
primaryDf[(primaryDf["recordingId"] == 18) & (primaryDf["frame"] >= 6343) & (primaryDf["frame"] <= 7183)].head()
# Out:
#      index  recordingId  trackId  frame  trackLifetime   xCenter   yCenter  \
# 573    573           18      121   6977              0  45.84453 -10.80784
# 574    574           18      121   6987             10  46.12077 -11.16200
# 575    575           18      121   6997             20  46.40802 -11.52370
# 576    576           18      121   7007             30  46.70353 -11.88360
# 577    577           18      121   7017             40  47.03528 -12.23412
#
#        heading  width  length  xVelocity  yVelocity  xAcceleration  \
# 573  308.09315    0.0     0.0    0.66802   -0.87191        0.08182
# 574  308.47217    0.0     0.0    0.70205   -0.89765        0.08039
# 575  309.25283    0.0     0.0    0.73188   -0.90021        0.09496
# 576  310.30556    0.0     0.0    0.78471   -0.88973        0.10672
# 577  311.48046    0.0     0.0    0.81661   -0.84625        0.00980
#
#      yAcceleration  uniqueTrackId sceneId  roadWidth
# 573       -0.05376          18121      10        5.0
# 574       -0.03148          18121      10        5.0
# 575        0.01324          18121      10        5.0
# 576        0.06314          18121      10        5.0
# 577        0.07446          18121      10        5.0

# %%
allPedDfs[(allPedDfs["recordingId"] == 18) & (allPedDfs["frame"] >= 6343) & (allPedDfs["frame"] <= 7183)].head()
# Out:
#     index  recordingId  trackId  frame  trackLifetime   xCenter   yCenter  \
# 79    451           18      107   6593            250  63.26626 -30.59219
# 80    452           18      107   6603            260  63.14687 -30.00792
# 81    453           18      107   6613            270  62.95771 -29.47820
# 82    454           18      107   6623            280  62.77440 -28.96487
# 83    455           18      107   6633            290  62.54876 -28.51733
#
#       heading  width  length  xVelocity  yVelocity  xAcceleration  \
# 79  109.75296    0.0     0.0   -0.25921    1.50798       -0.09824
# 80  110.18068    0.0     0.0   -0.38003    1.40735       -0.24175
# 81  111.64278    0.0     0.0   -0.45945    1.30165       -0.15654
# 82  113.68235    0.0     0.0   -0.51511    1.19766       -0.20587
# 83  115.78968    0.0     0.0   -0.61459    1.08227       -0.21891
#
#     yAcceleration  uniqueTrackId sceneId  roadWidth    sceneX    sceneY
# 79       -0.02547          18107      10        5.0  1.240858 -2.909158
# 80       -0.23818          18107      10        5.0  1.247323 -2.312850
# 81       -0.23945          18107      10        5.0  1.174086 -1.755157
# 82       -0.27735          18107      10        5.0  1.103112 -1.214720
# 83       -0.16232          18107      10        5.0  0.976890 -0.729669

# %%
allPedDfs[(allPedDfs["recordingId"] == 18) & (allPedDfs["frame"] >= 6343) & (allPedDfs["frame"] <= 7183)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18107, 18112]
# Length: 2, dtype: Int64

# %%
allPedDfs[(allPedDfs["uniqueTrackId"] == 18121)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18121]
# Length: 1, dtype: Int64

# %%
allPedDfs[(allPedDfs["recordingId"] == 18) & (allPedDfs["frame"] <= 7183)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18023, 18042, 18053, 18069, 18090, 18107, 18112]
# Length: 7, dtype: Int64

# %%
allPedDfs[(allPedDfs["recordingId"] == 18) & (allPedDfs["frame"] >= 6343)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18107, 18112, 18121, 18127, 18134, 18156, 18162, 18166, 18168, 18180, 18181,
#  18201, 18204, 18214, 18225, 18248, 18273, 18279, 18280, 18281, 18298, 18304,
#  18306, 18311, 18319, 18322, 18337, 18344, 18382, 18388, 18396, 18408, 18420,
#  18422]
# Length: 34, dtype: Int64

# %%
allPedDfs[(allPedDfs["recordingId"] == 18)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18023, 18042, 18053, 18069, 18090, 18107, 18112, 18121, 18127, 18134, 18156,
#  18162, 18166, 18168, 18180, 18181, 18201, 18204, 18214, 18225, 18248, 18273,
#  18279, 18280, 18281, 18298, 18304, 18306, 18311, 18319, 18322, 18337, 18344,
#  18382, 18388, 18396, 18408, 18420, 18422]
# Length: 39, dtype: Int64

# %%
allPedDfs[(allPedDfs["frame"] <= 7183)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18023, 18042, 18053, 18069, 18090, 18107, 18112, 19040, 19045, 19047,
#  ...
#  29000, 29037, 29044, 29092, 29093, 29094, 29097, 29098, 29107, 29112]
# Length: 155, dtype: Int64

# %%
allPedDfs[(allPedDfs["frame"] >= 6343)]["uniqueTrackId"].unique()
# Out:
# <IntegerArray>
# [18107, 18112, 18121, 18127, 18134, 18156, 18162, 18166, 18168, 18180,
#  ...
#  29530, 29531, 29532, 29533, 29534, 29542, 29554, 29559, 29575, 29579]
# Length: 474, dtype: Int64
